# %%
### 현재 공유받은 사이트에 회사명만 크롤링 해서 주피터 노트북에 한줄씩 출력해주세요.

# %%
# 1. requests 불러오고 뷰티풀숲으로 불러오고

import requests
from bs4 import BeautifulSoup

url = "https://davelee-fun.github.io/blog/crawling_stock_example.html"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

#datas = soup.select("div.st_name")
datas = soup.select("ul.table-stock.sty1>li.row_sty") #select 형식으로 가져오면 리스트 형식으로 가져옴 li가 자식임 그래서 >!

# ul
#     li
#     li
#     li # 이런 목록을 만들기 위해 ul 안에 자식요소인 li 있음

for data in datas :
    # print(data.get_text().strip())
    print(data.select_one("div.st_name").get_text().strip().replace(" ", ""))
# Out:
# CJ씨푸드
# CJ씨푸드1우
# CJ제일제당
# CJ제일제당
# 우
# MH에탄올
# SPC삼립
# 고려산업
# 남양유업
# 남양유업우
# 농심
# 대상
# 대상우
# 대한제당
# 대한제당우
# 대한제분
# 동원F&B
# 롯데제과
# 롯데칠성
# 롯데칠성우
# 마니커
# 무학
# 보해양조
# 빙그레
# 사조대림
# 사조동아원
# 사조씨푸드
# 사조오양
# 삼양사
# 삼양사우
# 삼양식품
# 샘표식품
# 서울식품
# 서울식품우
# 선진
# 오뚜기
# 오리온
# 우성
# 조흥
# 크라운제과
# 크라운제과우
# 팜스코
# 풀무원
# 하이트진로
# 하이트진로2우B
# 한성기업
# 해태제과식품
# BYC
# BYC우
# F&F
# LF
# TBH글로벌
# 대한방직
# 대현
# 메타랩스
# 방림
# 비비안
# 성안
# 신영와코루
# 신원
# 쌍방울
# 원림
# 인디에프
# 일신방직
# 전방
# 태평양물산
# 한섬
# 한세실업
# 한세예스24홀딩스
# 형지엘리트
# 호전실업
# SUN&L
# 깨끗한나라
# 깨끗한나라우
# 대영포장
# 모나리자
# 무림P&P
# 무림페이퍼
# 삼정펄프
# 세하
# 신대양제지
# 아세아제지
# 영풍제지
# 유니드비티플러스
# 이건산업
# 태림포장
# 페이퍼코리아
# 한국수출포장
# 한솔제지
# 한솔홈데코
# 한창제지
# DL
# DL우
# DRB동일
# HDC현대EP
# KCC
# KG케미칼
# KPX케미칼
# KPX홀딩스
# LG생활건강
# LG생활건강우
# LG화학
# LG화학우
# LX하우시스
# LX하우시스우
# NPC
# NPC우
# OCI
# OCI
# PI첨단소재
# S-Oil
# S-Oil우
# SH에너지화학
# SKC
# SK이노베이션
# SK이노베이션우
# SK케미칼
# SK케미칼우
# TKG휴켐스
# WISCOM
# 강남제비스코
# 경농
# 경인양행
# 국도화학
# 그린케미칼
# 극동유화
# 금양
# 금호석유
# 금호석유우
# 금호타이어
# 남해화학
# 넥센
# 넥센우
# 넥센타이어
# 넥센타이어1우B
# 노루페인트
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://davelee-fun.github.io/blog/crawling_stock_example.html"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")


datas = soup.select("ul.table-stock.sty1>li.row_sty>div.st_name")

for data in datas :
    print(data.get_text().strip().replace(" ", ""))
# Out:
# CJ씨푸드
# CJ씨푸드1우
# CJ제일제당
# CJ제일제당
# 우
# MH에탄올
# SPC삼립
# 고려산업
# 남양유업
# 남양유업우
# 농심
# 대상
# 대상우
# 대한제당
# 대한제당우
# 대한제분
# 동원F&B
# 롯데제과
# 롯데칠성
# 롯데칠성우
# 마니커
# 무학
# 보해양조
# 빙그레
# 사조대림
# 사조동아원
# 사조씨푸드
# 사조오양
# 삼양사
# 삼양사우
# 삼양식품
# 샘표식품
# 서울식품
# 서울식품우
# 선진
# 오뚜기
# 오리온
# 우성
# 조흥
# 크라운제과
# 크라운제과우
# 팜스코
# 풀무원
# 하이트진로
# 하이트진로2우B
# 한성기업
# 해태제과식품
# BYC
# BYC우
# F&F
# LF
# TBH글로벌
# 대한방직
# 대현
# 메타랩스
# 방림
# 비비안
# 성안
# 신영와코루
# 신원
# 쌍방울
# 원림
# 인디에프
# 일신방직
# 전방
# 태평양물산
# 한섬
# 한세실업
# 한세예스24홀딩스
# 형지엘리트
# 호전실업
# SUN&L
# 깨끗한나라
# 깨끗한나라우
# 대영포장
# 모나리자
# 무림P&P
# 무림페이퍼
# 삼정펄프
# 세하
# 신대양제지
# 아세아제지
# 영풍제지
# 유니드비티플러스
# 이건산업
# 태림포장
# 페이퍼코리아
# 한국수출포장
# 한솔제지
# 한솔홈데코
# 한창제지
# DL
# DL우
# DRB동일
# HDC현대EP
# KCC
# KG케미칼
# KPX케미칼
# KPX홀딩스
# LG생활건강
# LG생활건강우
# LG화학
# LG화학우
# LX하우시스
# LX하우시스우
# NPC
# NPC우
# OCI
# OCI
# PI첨단소재
# S-Oil
# S-Oil우
# SH에너지화학
# SKC
# SK이노베이션
# SK이노베이션우
# SK케미칼
# SK케미칼우
# TKG휴켐스
# WISCOM
# 강남제비스코
# 경농
# 경인양행
# 국도화학
# 그린케미칼
# 극동유화
# 금양
# 금호석유
# 금호석유우
# 금호타이어
# 남해화학
# 넥센
# 넥센우
# 넥센타이어
# 넥센타이어1우B
# 노루페인트
# ...

# %%
### 현재 크롤링 해온 데이터에서 주식금액이랑 변동률 출력하세요

# %%
import requests
from bs4 import BeautifulSoup

url = "https://davelee-fun.github.io/blog/crawling_stock_example.html"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

datas = soup.select("ul.table-stock.sty1>li.row_sty")
# for data in datas : div.st_rate
for data in datas:
    price = data.select_one("div.st_price").get_text().strip().replace(" ", "")
    rate = data.select_one("div.st_rate").get_text().strip().replace(" ", "").replace("\n", "")
    print(f"{price} / {rate}")
    # print(f"주식금액 : {data.select_one("div.st_price").get_text().strip().replace(" ", "")}",
    #        f"변동률 : {data.select_one("div.st_rate").get_text().strip().replace(" ", "")}")
# Out:
# 3,705 / -0.94%
# 25,300 / 0.20%
# 321,500 / -0.77%
# 150,300 / 0.20%
# 7,580 / 0.00%
# 74,400 / -1.06%
# 4,505 / 1.81%
# 504,000 / -0.20%
# 286,500 / 0.88%
# 448,000 / -0.88%
# 18,910 / -1.51%
# 15,350 / -0.39%
# 3,735 / 2.89%
# 3,225 / 3.53%
# 138,500 / -0.93%
# 31,950 / -1.54%
# 110,500 / 0.18%
# 139,900 / -0.71%
# 67,400 / 0.00%
# 1,467 / -0.81%
# 5,700 / -1.04%
# 609 / 1.00%
# 49,150 / 0.72%
# 29,350 / -0.34%
# 1,134 / 0.71%
# 5,750 / -0.69%
# 8,410 / -2.77%
# 45,200 / 2.03%
# 28,150 / 0.36%
# 120,000 / -0.83%
# 29,250 / 0.17%
# 222 / -0.45%
# 2,400 / -2.04%
# 9,270 / 0.98%
# 452,000 / -0.99%
# 125,100 / -0.08%
# 25,150 / -0.98%
# 208,000 / 0.00%
# 9,040 / -0.88%
# 11,120 / -0.71%
# 4,840 / 1.57%
# 11,370 / -1.04%
# 22,650 / 1.12%
# 16,550 / 0.36%
# 6,010 / -0.83%
# 6,090 / -0.98%
# 416,000 / -0.48%
# 150,000 / 0.00%
# 131,800 / 0.92%
# 16,570 / 0.36%
# 1,839 / 0.11%
# 54,200 / 0.37%
# 2,250 / 0.45%
# 3,660 / 16.56%
# 7,430 / 1.64%
# 1,353 / 0.37%
# 2,245 / 0.00%
# ...

# %%
url = "https://davelee-fun.github.io/blog/crawling_stock_example.html"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

datas = soup.select("ul.table-stock.sty1>li.row_sty")

for data in datas :
    company = data.select_one("div.st_name").get_text().strip().replace(" ", "").replace("/n", "")
    price = data.select_one("div.st_price").get_text().strip().replace(" ", "")
    rate = data.select_one("div.st_rate").get_text().strip().replace(" ", "").replace("/n", "")
    # print(data.select_one("div.st_name").get_text().strip().replace(" ", "").replace("/n", "")
    # print(data.select_one("div.st_price").get_text().strip().replace(" ", "")
    # print(data.select_one("div.st_rate").get_text().strip().replace(" ", "").replace("/n", "")
    print(f"{company} : {price}원 / {rate}")
# Out:
# CJ씨푸드 : 3,705원 / -0.94
# %
# CJ씨푸드1우 : 25,300원 / 0.20%
# CJ제일제당 : 321,500원 / -0.77
# %
# CJ제일제당
# 우 : 150,300원 / 0.20%
# MH에탄올 : 7,580원 / 0.00%
# SPC삼립 : 74,400원 / -1.06
# %
# 고려산업 : 4,505원 / 1.81%
# 남양유업 : 504,000원 / -0.20
# %
# 남양유업우 : 286,500원 / 0.88%
# 농심 : 448,000원 / -0.88
# %
# 대상 : 18,910원 / -1.51
# %
# 대상우 : 15,350원 / -0.39
# %
# 대한제당 : 3,735원 / 2.89%
# 대한제당우 : 3,225원 / 3.53%
# 대한제분 : 138,500원 / -0.93
# %
# 동원F&B : 31,950원 / -1.54
# %
# 롯데제과 : 110,500원 / 0.18%
# 롯데칠성 : 139,900원 / -0.71
# %
# 롯데칠성우 : 67,400원 / 0.00%
# 마니커 : 1,467원 / -0.81
# %
# 무학 : 5,700원 / -1.04
# %
# 보해양조 : 609원 / 1.00%
# 빙그레 : 49,150원 / 0.72%
# 사조대림 : 29,350원 / -0.34
# %
# 사조동아원 : 1,134원 / 0.71%
# 사조씨푸드 : 5,750원 / -0.69
# %
# 사조오양 : 8,410원 / -2.77
# %
# 삼양사 : 45,200원 / 2.03%
# 삼양사우 : 28,150원 / 0.36%
# 삼양식품 : 120,000원 / -0.83
# %
# 샘표식품 : 29,250원 / 0.17%
# 서울식품 : 222원 / -0.45
# %
# 서울식품우 : 2,400원 / -2.04
# %
# 선진 : 9,270원 / 0.98%
# 오뚜기 : 452,000원 / -0.99
# %
# 오리온 : 125,100원 / -0.08
# %
# ...
