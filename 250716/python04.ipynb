# %%
from bs4 import BeautifulSoup

xmldata = """
<?xml version="1.0" encoding="UTF-8" standalone="yes"?>
<response>
    <header>
        <resultCode>0000</resultCode>
        <resultMsg>OK</resultMsg>
    </header>
    <body>
        <items>
            <item>
                <contentId>100585</contentId>
                <facltNm>에스원캠프</facltNm>
                <lineIntro></lineIntro>
                <intro></intro>
                <allar>0</allar>
                <insrncAt>Y</insrncAt>
                <trsagntNo>2022-25</trsagntNo>
                <bizrno></bizrno>
                <facltDivNm>민간</facltDivNm>
                <mangeDivNm>직영</mangeDivNm>
                <mgcDiv>성대봉</mgcDiv>
                <manageSttus>운영</manageSttus>
                <hvofBgnde></hvofBgnde>
                <hvofEnddle></hvofEnddle>
                <featureNm></featureNm>
                <induty>일반야영장</induty>
                <lctCl>산,숲</lctCl>
                <doNm>경기도</doNm>
                <sigunguNm>포천시</sigunguNm>
                <zipcode>11108</zipcode>
                <addr1>경기 포천시 영북면 대회산길 79-28</addr1>
                <addr2></addr2>
                <mapX>127.238382563773</mapX>
                <mapY>38.066958754657</mapY>
                <direction></direction>
                <tel></tel>
                <homepage></homepage>
                <resveUrl></resveUrl>
                <resveCl>온라인실시간예약</resveCl>
                <manageNmpr>0</manageNmpr>
                <gnrlSiteCo>0</gnrlSiteCo>
                <autoSiteCo>18</autoSiteCo>
                <glampSiteCo>0</glampSiteCo>
                <caravSiteCo>0</caravSiteCo>
                <indvdlCaravSiteCo>0</indvdlCaravSiteCo>
                <sitedStnc>0</sitedStnc>
                <siteMg1Width>0</siteMg1Width>
                <siteMg2Width>0</siteMg2Width>
                <siteMg3Width>0</siteMg3Width>
                <siteMg1Vrticl>0</siteMg1Vrticl>
                <siteMg2Vrticl>0</siteMg2Vrticl>
                <siteMg3Vrticl>0</siteMg3Vrticl>
                <siteMg1Co>18</siteMg1Co>
                <siteMg2Co>0</siteMg2Co>
                <siteMg3Co>0</siteMg3Co>
                <siteBottomCl1>0</siteBottomCl1>
                <siteBottomCl2>18</siteBottomCl2>
                <siteBottomCl3>0</siteBottomCl3>
                <siteBottomCl4>0</siteBottomCl4>
                <siteBottomCl5>0</siteBottomCl5>
                <tooltip></tooltip>
                <glampInnerFclty></glampInnerFclty>
                <caravInnerFclty></caravInnerFclty>
                <prmisnDe>2022-08-31</prmisnDe>
                <operPdCl>봄,여름,가을,겨울</operPdCl>
                <operDeCl>평일+주말</operDeCl>
                <trlerAcmpnyAt>N</trlerAcmpnyAt>
                <caravAcmpnyAt>N</caravAcmpnyAt>
                <toiletCo>0</toiletCo>
                <swrmCo>0</swrmCo>
                <wtrplCo>0</wtrplCo>
                <brazierCl>개별</brazierCl>
                <sbrsCl>전기,무선인터넷,장작판매,온수,트렘폴린,물놀이장,운동시설</sbrsCl>
                <sbrsEtc></sbrsEtc>
                <posblFcltyCl>어린이놀이시설</posblFcltyCl>
                <posblFcltyEtc></posblFcltyEtc>
                <clturEventAt>N</clturEventAt>
                <clturEvent></clturEvent>
                <exprnProgrmAt>N</exprnProgrmAt>
                <exprnProgrm></exprnProgrm>
                <extshrCo>0</extshrCo>
                <frprvtWrppCo>0</frprvtWrppCo>
                <frprvtSandCo>0</frprvtSandCo>
                <fireSensorCo>0</fireSensorCo>
                <themaEnvrnCl>봄꽃여행,가을단풍명소</themaEnvrnCl>
                <eqpmnLendCl></eqpmnLendCl>
                <animalCmgCl>불가능</animalCmgCl>
                <tourEraCl></tourEraCl>
                <firstImageUrl>https://gocamping.or.kr/upload/camp/100585/thumb/thumb_720_5542ovuAMlE0bpOotiCyHlcu.jpg</firstImageUrl>
                <createdtime>2023-01-16 16:49:25</createdtime>
                <modifiedtime>2025-07-16 06:30:01</modifiedtime>
            </item>
        </items>
    </body>
</response>
"""

soup = BeautifulSoup(xmldata, "lxml")
#print(soup.find_all("addr1"))
data = soup.find_all("item")
for item in data :
    name = item.find("facltnm")
    addr = item.find("addr1")
    print(f"캠핑장명 : {name.get_text()}, 주소 : {addr.get_text()}")
# Out:
# 캠핑장명 : 에스원캠프, 주소 : 경기 포천시 영북면 대회산길 79-28
