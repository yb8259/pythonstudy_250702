# %%
import json 

data = """
{
    "id":"01", "language":"python", "edition":"third", "author":"David",
    "history":
        [
            {
                "date":"2025-07-16",
                "item":"iPhone"
            },
            {
                "date":"2025-03-11",
                "item":"Android"
            }
        ]
}
""" #json 데이터 클라이언트와 통신하는..! 딕셔너리랑 달라요~ 딕셔너리 형태로 되어있긴 하나 앞뒤 """ 추가하면 제이슨으로 인식함

json_data = json.loads(data)
#print(json_data)
print(json_data["history"][0]["date"]) #히스토리만 찾아와~
# Out:
# 2025-07-16

# %%
import json

data = """
{
    "lastBuildDate": "Wed, 16 Jul 2025 13:20:21 +0900",
    "total": 1261632,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "[비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2",
            "link": "https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5038779/50387791565.jpg",
            "lprice": "41900",
            "hprice": "",
            "mallName": "무신사",
            "productId": "50387791565",
            "productType": "2",
            "brand": "비비앙",
            "maker": "",
            "category1": "화장품/미용",
            "category2": "향수",
            "category3": "여성향수",
            "category4": ""
        },
         {
            "title": "[보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK",
            "link": "https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5280188/52801887678.jpg",
            "lprice": "84990",
            "hprice": "",
            "mallName": "무신사",
            "productId": "52801887678",
            "productType": "2",
            "brand": "보니데",
            "maker": "",
            "category1": "스포츠/레저",
            "category2": "수영",
            "category3": "여성수영복",
            "category4": "원피스수영복"
        },
        {
            "title": "[피지컬가먼츠] P2407 메쉬배색 기능성 오버핏반팔 [블랙] P2407",
            "link": "https://link.musinsa.com/app/goods/4128907?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_4777637/47776373129.jpg",
            "lprice": "26890",
            "hprice": "",
            "mallName": "무신사",
            "productId": "47776373129",
            "productType": "2",
            "brand": "피지컬가먼츠",
            "maker": "",
            "category1": "패션의류",
            "category2": "남성의류",
            "category3": "티셔츠",
            "category4": ""
        }
    ]
}
"""

json_data = json.loads(data)
#print(json_data)

#print(json_data["items"])
print(json_data["items"][0]["title"])
# Out:
# [비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2

# %%
import requests
import pprint
import openpyxl

client_id = "2Js18oH5QFiz5_TTb2B_"
client_secret = "Uyir8OFQcB"
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크"])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=무신사&display=100&start="+str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    
    res = requests.get(naver_open_api,headers = header_params)
    #print(res.content)
    
    if res.status_code == 200:
        data= res.json()
        #pprint.pprint(data)
        for item in data["items"]:
            num += 1
            excel_sheet.append([num,item["title"],item["link"]])
            print(num,item["title"], item["link"])
    else : 
        print("Error Code :",res.status_code)

excel_file.save("shopping_with_무신사.xlsx")
excel_file.close()
# Out:
# 1 [비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2 https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 2 [보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 3 [피지컬가먼츠] P2407 메쉬배색 기능성 오버핏반팔 [블랙] P2407 https://link.musinsa.com/app/goods/4128907?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 4 [마뗑킴] ACCORDION MINI BAG IN SILVER MK2400BG730MSV https://link.musinsa.com/app/goods/3024801?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 5 [토앤토] x 로우클래식 플립플랍 Zerovity 크림 Z-FF-LCCR https://link.musinsa.com/app/goods/3320672?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# ...

# %%
import requests
import pprint
import openpyxl

client_id = "2Js18oH5QFiz5_TTb2B_"
client_secret = "Uyir8OFQcB"
start, num = 1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "날짜", "블로거"])

for index in range(10):
    start_number = start + (index*100)
    naver_open_API = "https://openapi.naver.com/v1/search/blog.json?query=블렌더&display=100&start="+str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}

    res = requests.get(naver_open_API, headers = header_params)

    if res.status_code == 200 :
        data =res.json()
        for item in data["items"]:
            num+=1
            excel_sheet.append([num, item["title"],item["postdate"],item["bloggername"]])
            print(num,item["title"],item["postdate"],item["bloggername"])    

    else :
        print("Error Code : res.status_code")   

excel_file.save("shopping_with_블렌더.xlsx")
excel_file.close()
# Out:
# 1 진공<b>블렌더</b> 추천 소음 없는 자동세척 믹서기 20250711 세상에서 빛나는 특별한 존재
# 2 언니네 산지직송2 파김치 필립스 믹서기 프로파워 <b>블렌더</b>...  20250714 느릿하게 따스하게_넷
# 3 강력한 휴대용믹서기 닌자 무선 블라스트 포터블 <b>블렌더</b> 후기 20250625 sweet sweet life
# 4 수프? 쉽지~ 닌자 가열<b>블렌더</b> 콜드 앤 핫 HB150KR 리뷰 20250622 정돈일기
# 5 풀무원파워플랫<b>블렌더</b>, 주방의 무드를 바꾸는 변화 20250714 Stay luxe, Travel slow
# 6 코스트코 닌자 무선 <b>블렌더</b> 요거트 스무디 만들기 20250706 맛집찾아삼만리
# 7 <b>블렌더</b>3d, 왜 이렇게 어렵게 느껴질까? 쉽게 입문할 수 있는...  20250628 JK Dreams 스튜디오
# 8 샤크 닌자 블라스트 <b>블렌더</b> 프라이빗 팝업스토어 이벤트...  20250621 매거진 8(Magazine PAL)
# 9 에어메이드 <b>블렌더</b> 장점 리뷰 및 34%할인 구매 방법 20250711 가위남(가족을 위해 요리하는 남자)
# 10 저소음믹서기 추천 가정용 진공<b>블렌더</b> 샤크닌자 콰이어트 20250715 실전육아전문가의 비타민육아
# 11 책 [<b>블렌더</b> 3D &amp; AI] 살펴보기 20250420 폭주달팽이 블로그
# 12 뭉툭한 날로 안전하고 강력한 미국 프리미엄 <b>블렌더</b> 블렌텍...  20250712 신유딩 놀이터
# 13 오트밀 우유 만들기 조용한 닌자 진공 <b>블렌더</b> Quite IQ...  20250524 플러키비비의 맛있는 김밥 lab
# 14 저소음믹서기 추천 : 가정용 고속 <b>블렌더</b> 닌자 20250628 lovely B
# 15 해피콜믹서기 이유식 추천 해피콜사계절<b>블렌더</b> 20250606 엣피의 효율살림
# ...

# %%
import requests
import pprint

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 25
excel_sheet.column_dimensions["C"].width = 25
excel_sheet.column_dimensions["D"].width = 100
excel_sheet.append(["No", "제목", "개봉 날짜", "줄거리", "평점"])

url = "https://api.themoviedb.org/3/movie/now_playing?language=ko-KR&page=1"
start, num = 1, 0
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNjFmOGUzMzI0MGY4NDJkMjM5N2YyMzU1ZDU0NzcyOSIsIm5iZiI6MTc1MjE1MzY2My4wMTksInN1YiI6IjY4NmZiZTNmYmJhODViNWJhNDU0MTBlZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.eCvIYkoFxaoQ8YsS6Z3nxD-QC6Ndu3O0esbKJgxADl0"
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    data = response.json()
    for item in data["results"]:
        num += 1
        excel_sheet.append([num,item["title"], item["release_date"], item["overview"],item["vote_average"]])
        print(num, item["title"], item["release_date"], item["overview"],item["vote_average"])

else : print("Error Code :", response.status_code)

excel_file.save("tmbd_250716.xlsx")
excel_file.close()
# Out:
# 1 가라데 키드: 레전드 2025-05-08 서로 다른 세대의 스승 미스터 한(성룡)과 다니엘 라루소(랄프 마치오)가 소년 ‘리’를 중심으로 힘을 합치며 펼쳐지는 무술 성장 드라마. 과거의 철학과 기술을 계승한 두 사부는 삶의 벽에 부딪힌 리에게 가라데의 진정한 의미를 전하며 함께 성장한다. 7.309
# 2 어쩌다 파트너 2025-07-10 동네 치안을 위해 헌신하는 열정 넘치는 단속 요원과 이 지역으로 좌천된 저돌적인 전직 형사. 두 사람이 어쩔 수 없이 한 팀이 되면서 로테르담 거리에 예측 불허의 상황이 펼쳐진다. 5.63
# 3 슈퍼맨 2025-07-09 슈퍼맨은 오늘도 세계 곳곳의 위협에 맞서 싸우지만, 시민들의 반응은 극과 극으로 갈린다. 한편, 렉스 루터는 슈퍼맨을 무너뜨릴 비밀을 손에 넣고 역대 최강의 슈퍼-빌런들과 함께 총 공격에 나선다. 슈퍼맨은 첫 패배와 함께 이들의 계속된 공세에 직면하고 모든 것을 바로잡기 위해 슈퍼독 크립토와 함께 맞서게 되는데... 과연 그는 이 전례 없는 위기에서 다시 날아오를 수 있을까? 7.4
# 4 발레리나 2025-06-04 살해당한 아버지의 복수를 원하는 이브는 전설적인 킬러 존 윅을 배출한 암살자 양성 조직 루스카 로마에서 혹독한 훈련을 거쳐 발레리나이자 킬러로 성장한다. 아버지의 죽음에 얽힌 자들을 쫓던 이브는 루스카 로마를 뛰어넘는 거대한 조직의 정체를 알아차리게 되고, 킬러들의 표적이 된 이브의 눈앞에 존 윅이 나타나는데… 7.464
# ...
