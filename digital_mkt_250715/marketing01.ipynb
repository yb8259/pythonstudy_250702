# %%
import requests
from bs4 import BeautifulSoup
from openpyxl import Workbook # 워크북을 통해서 엑셀을 만들고 시트 찾아오고 이름 붙이고 엑셀 최종 만듬

url = "https://www.kurly.com/goods/5063069"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

test = soup.select("css-y49dcn e36z05c13")
# Out:
# <!DOCTYPE html>
# ...

# %%
#import selenium 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
#selenium.webdriver.chrome.options.Options
#selenium.webdriver.chrome()
from bs4 import BeautifulSoup
import time 

#1. 셀레니움 기본 옵션 설정
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("headless")

driver = webdriver.Chrome(options = options)

#2. 페이지 접속
url = "https://www.kurly.com/goods/5063069"
driver.get(url)

time.sleep(5) #페이지 로딩대기 시간 설정

#3. HTML 가져오기
soup = BeautifulSoup(driver.page_source, "html.parser")

#4. review 텍스트 추출하기
reviews = soup.select("p.css-y49dcn.e36z05c13")
for review in reviews :
    print(review.get_text().strip())

driver.quit()
# Out:
# 감자밭 감자빵 오리지널, 지인이 예전에 한 번 사다줬던 걸 먹어보고 그 맛이 잊히질 않아서 결국 할인할 때 구매했어요.
# 가격대는 살짝 있는 편이지만, 먹어보면 왜 인기 있는지 알 수 있을 정도로 만족스러웠어요.
# 빵 피가 쫀득쫀득하면서도 담백하고, 안에 들어있는 감자 속도 풍미가 깊고 고소해서 너무 맛있어요.
# 일반 감자빵과는 확실히 다른 퀄리티! 전자레인지에 살짝 돌리면 갓 나온 듯한 따뜻한 식감까지 느껴져서 더욱 맛있게 즐길 수 있었어요.
# 출출할 때 간식으로도 든든하고, 커피랑 함께 먹으니 조합도 완벽하더라고요. 감자 좋아하시는 분이라면 무조건 추천하고 싶은 빵이에요.
# 감자빵 오리지날맛 맛있어서 마켓컬리에서
# 여러번 구매해먹었는데 정성스런 리뷰는 처음 써봐요ㅎㅎ
# 빵은 쫄깃쫄깃한 떡이랑 비슷한 찰진 식감에 속에는 포슬포슬한 으깬 감자가 많이 들어있어서 포슬포슬 너무 맛있어요.
# 간도 자극적이지 않고, 개인적으로 고구마보다
# 담백한 감자를 선호하는데 간식으로 최고에요~
# 모양도 동글동글한 감자 모양이라 먹음직스럽고, 감자빵 은근 중독성 있어서 자꾸 구입하게 되네요.
# 낱개 포장이라 위생적이구요.
# 간편하게 하나씩 꺼내 전자렌지에 봉지만 살짝 뜯어서 따끈하게 돌려서 먹으면 쭉쭉 늘어나서 넘나 맛있어요.
# 감자빵 자주 사먹게 할인 많이 해주면 좋겠어요ㅎ
# 이것은 감자빵보다는 갓자빵이라고 불러야 할 것 같아요
# 이 맛있는걸 나만 여태 모르고 살았다니…
# 겉은 쫀득 속은 포슬! 이렇게 쫀득쫀득 말랑하다니!!
# 냉동고에 보관했다가 전자레인지 해동 1분 30초면 말랑해집니다
# 더 따뜻하게 드시고 싶으면 전자레인지 30초~1분 돌려주시면 좋고 저처럼 특별하게 감자플 만들어 드셔도 좋을 것 같아요
#
# 저는 해동 후 와플기계에 5분 구워줬고 따뜻할 때 바로 먹으니 쫀득바삭의 극치…
# 제 와플팬은 좀 작은 편이라 속에 있는 감자가 터져나와 모양은 좀 웃기지만 쫀득한 겉부분과 포슬한 감자속이 와플팬에 눌러져 바삭바삭 너무 맛있어요
# ...

# %%
#import selenium 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
#selenium.webdriver.chrome.options.Options
#selenium.webdriver.chrome()
from bs4 import BeautifulSoup
import time 
from openpyxl import Workbook

#1. 셀레니움 기본 옵션 설정
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("headless")

driver = webdriver.Chrome(options = options)

#2. 페이지 접속
url = "https://www.kurly.com/goods/5063069"
driver.get(url)

time.sleep(5) #페이지 로딩대기 시간 설정

#3. HTML 가져오기
soup = BeautifulSoup(driver.page_source, "html.parser")

#4. review 텍스트 추출하기
reviews = soup.select("p.css-y49dcn.e36z05c13")
review_lists = [ review.get_text().strip() for review in reviews]

driver.quit()

wb = Workbook()
ws = wb.active
ws.title = "Kurly Reviews"

ws.append(["리뷰 내용"])
for item in review_lists : 
    ws.append([item])

wb.save("Kurly_Reviews.xlsx")
print("엑셀 저장 완료 : Kurly Reviews.xlsx")
# Out:
# 엑셀 저장 완료 : Kurly Reviews.xlsx
