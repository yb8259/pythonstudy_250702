# %% [markdown]
# #### 1. 네이버 뉴스에서 '디지털 마케팅' 키워드로 검색한 뉴스 제목 10개를 수집하세요.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

service=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

query = "디지털 마케팅"
url = f"https://search.naver.com/search.naver?where=news&query={query}"

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"}

driver.get(url)

elements = driver.find_elements(By.CSS_SELECTOR,"span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1.sds-comps-text-type-headline1")
for i, element in enumerate(elements[:10],1):
    print(f"{i}. {element.text}")
driver.quit()
# Out:
# 1. NH투자증권, 상반기 순익 10% 증가…하반기 디지털 채널 강화 힘 받아
# 2. 애경산업, 2Q 영업익 112억 36%↓ "브랜드·마케팅 투자 강화 영향"
# 3. KT, GS리테일 1000여 매장 디지털 광고 플랫폼 구축
# 4. KT-GS리테일, '리테일 미디어' 진출 "디지털 광고 플랫폼 제공 완료"
# 5. [영양 소식] 경북경제진흥원 등과 '고추 공동마케팅' 협약
# 6. 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공략
# 7. 스토어링크, '문도 픽사' 통합 마케팅 진행
# 8. 애경산업, 2분기 영업익 전년비 36%↓ "브랜드·마케팅 투자 강화 영향"
# 9. 인천 웰니스관광, 글로벌 OTA 연계 해외마케팅 본격화
# 10. “현대미술과 OLED의 조화”⋯ LG전자, 국현미와 ‘디지털 전시’

# %%
import requests
from bs4 import BeautifulSoup

query = "디지털 마케팅"
url = f"https://search.naver.com/search.naver?where=news&query={query}"

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("a.CZ2lJrtx8_tIIyyaEDkQ.IQnq6B4xVFZbhCOvK9Fy")
for i, title in enumerate(titles[:10],1):
    print(f"{i}. {title.get_text().strip()}")
# Out:
# 1. NH투자증권, 상반기 순익 10% 증가…하반기 디지털 채널 강화 힘 받아
# 2. 애경산업, 2Q 영업익 112억 36%↓ "브랜드·마케팅 투자 강화 영향"
# 3. KT, GS리테일 1000여 매장 디지털 광고 플랫폼 구축
# 4. [영양 소식] 경북경제진흥원 등과 '고추 공동마케팅' 협약
# 5. KT-GS리테일, '리테일 미디어' 진출 "디지털 광고 플랫폼 제공 완료"
# 6. 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공략
# 7. 스토어링크, '문도 픽사' 통합 마케팅 진행
# 8. 애경산업, 2분기 영업익 전년비 36%↓ "브랜드·마케팅 투자 강화 영향"
# 9. 인천 웰니스관광, 글로벌 OTA 연계 해외마케팅 본격화
# 10. “현대미술과 OLED의 조화”⋯ LG전자, 국현미와 ‘디지털 전시’

# %% [markdown]
# #### 2. "다음 뉴스에서 IT섹션의 기사 제목과 링크를 수집하세요."
# https://news.daum.net/tech

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/tech"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"}

response = requests.get(url, headers=headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

articles = soup.select("ul.list_newsheadline2 li a.item_newsheadline2")
for i, article in enumerate(articles, 1):
    print(f"{i}. {article.text.strip()} \n {article["href"]}")
# Out:
# 1. “상상도 못했다” 갤레기 조롱받던 40대 아재폰, 연달아 ‘대박’…삼성 살렸다 [헤럴드경제=권제인 기자] “위기의 삼성, 스마트폰이 또 살렸다.” 삼성전자의 플래그십 스마트폰이 연달아 흥행 성공하면서 MX(모바일경험) 부문 실적 상승의 ‘1등 공신’이 됐다. 상반기 출시된 갤럭시 S25가 1분기에 이어 2분기에도 판매 호조를 기록했고, 하반기 출시한 폴더블폰도 역대급 ‘대박’을 터트리고 있다. 31일 삼성전자에 따르면 MX부문 매 헤럴드경제 22분 전
#  https://v.daum.net/v/20250731224150450
# 2. “일본 여행 취소해야겠어” 여기저기 감염병 난리…이 ‘백신’ 반드시 맞아야 헤럴드경제 1시간 전
#  https://v.daum.net/v/20250731214209216
# 3. 스탯, 엔터프라이즈 멤버십 신규 멤버 발표...스토리(IP)·펏지펭귄(PENGU)·타이코(TAIKO) 등 합류 한국경제 2시간 전
#  https://v.daum.net/v/20250731210147070
# 4. “이러다 다 죽는다!” 2000억 넘게 쏟아붓는데…한국 ‘꼴찌’ 망신, 큰일난다 헤럴드경제 3시간 전
#  https://v.daum.net/v/20250731194150078
# 5. 350년 만에 영국 첫 여성 왕실 천문학자 탄생 동아사이언스 3시간 전
#  https://v.daum.net/v/20250731193947046
# 6. [기획] 악마는 디테일에 있다… ‘농업포함’ ‘수익 90%’ 뇌관될 수도 디지털타임스 4시간 전
#  https://v.daum.net/v/20250731191502563
# 7. 유튜브 라이트 요금제 임박… 음원 앱 시장의 ‘게임체인저’ 될까? 이데일리 4시간 전
#  https://v.daum.net/v/20250731190814417
# 8. [단독] “타당성 연구에만 4억원 들었는데”…우주청 1조짜리 대표사업 퇴짜 맞은 이유가 매일경제 4시간 전
#  https://v.daum.net/v/20250731190600374
# 9. “유명 대기업도 당했다!” ‘엄친아’인 줄 알았는데…결국 터질 게 터졌다 헤럴드경제 4시간 전
#  https://v.daum.net/v/20250731184152756

# %% [markdown]
# #### 3. yes24의 경제 베스트셀러 1~10위 도서 제목과 저자를 수집하세요.

# %%
import requests
from bs4 import BeautifulSoup

url ="https://www.yes24.com/product/category/bestseller?categoryNumber=001001025"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

books = soup.select("ul#yesBestList > li")
for i, book in enumerate(books[:10],1):
    book_t = book.select_one("div.info_row.info_name a.gd_name")
    author_t = book.select_one("div.info_row.info_pubGrp span.authPub.info_auth")

    if book_t and author_t : # 두개의 값이 none이 아닐떄만!
        title = book_t.get_text().strip()
        author = author_t.get_text().strip()
        print(f"{i}. {title} - {author}")
# Out:
# 1. 박곰희 연금 부자 수업 - 박곰희 저
# 2. 인생을 바꾸는 최고의 ETF - 잼투리 저
# 3. 초보자를 단숨에 고수로 만드는 주식투자 핵심 수업 - 이정윤 저
# 4. 새로운 질서 - 헨리 A. 키신저, 에릭 슈미트, 크레이그 먼디 저/이현 역
# 5. 글로벌 주식 투자 빅 시프트 - 메리츠증권 리서치센터 저
# 6. 듀얼 브레인 - 이선 몰릭 저/신동숙 역
# 7. 돈의 심리학 (30만 부 기념 스페셜 에디션) - 모건 하우절 저/이지연 역
# 8. 이웃집 백만장자 (리미티드 에디션) - 토머스 J. 스탠리, 윌리엄 D. 댄코 저/홍정희 역
# 9. 부동산 투자 황금 로드맵 - 김원철 저
# 10. 재테크농부의 올라운드 투자 - 재테크농부 저

# %% [markdown]
# #### 4. 기상청 날씨 페이지에서 오늘의 전국 날씨 요약을 추출하세요.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.weather.go.kr/w/weather/forecast/short-term.do"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
weather = soup.select_one("div.cmp-view-content p.summary")
if weather :
    print(f"전국 날씨 요약 :")
    print(weather.get_text().strip())
else :
    print("날씨 요약 정보를 찾을 수 없습니다")
# Out:
# 전국 날씨 요약 :
# □  (종합) 당분간 무더위와 열대야 주의, 서해안과 남해안, 제주도해안 너울 유의○  (오늘, 31일) 남부지방 대체로 맑겠으나, 중부지방과 제주도 구름많음,
#                   밤(18~24시)까지 서울.인천.경기북부와 강원영서중.북부 곳에 따라 0.1mm 미만의 빗방울○  (내일, 8월 1일) 전국 가끔 구름많음,
#                      오후(12~18시) 강원북부산지 곳에 따라 소나기 ○  (모레, 8월 2일) 전국 가끔 구름많음,
#                      오후(12~18시) 강원내륙.산지 곳에 따라 소나기○  (글피, 8월 3일) 전국 가끔 구름많다가, 차차 흐려짐,
#                      밤(18~24시)부터 제주도 비○  (그글피, 8월 4일) 전국 대체로 흐림,
#                        제주도 곳에 따라 비, 오전(06~12시)부터 충남서해안과 전라서부 비 시작, 오후(12~18시)부터 밤(18~24시) 사이 수도권과 충청권, 전라권 곳에 따라 비
# *  예상 강수량(31일~8월 1일 오전)-  (수도권) 서해5도: 5mm 내외
# *  소나기에 의한 예상 강수량(8월 1일)-  (강원도) 강원북부산지: 5~20mm
# *  소나기에 의한 예상 강수량(8월 2일)-  (강원도) 강원내륙.산지: 5~40mm

# %% [markdown]
# #### 5. 잡코리아에 '데이터 분석가' 직무 공고 제목 20개를 수집하세요.

# %%
import requests
from bs4 import BeautifulSoup

stext = "데이터 분석가"
url = f"https://www.jobkorea.co.kr/Search/?stext={stext}"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

works = soup.select("div.styles_mb_space8__dk46ts1p a.sn28bt0")
for i, work in enumerate(works[0:20],1):
    print (f"{i}. {work.get_text().strip()}")
# Out:
# 1. 데이터 분석가 (경력)
# 2. 데이터 분석가
# 3. [CVS] 데이터 분석가(Business Analyst)
# 4. [쿡앱스] 게임 데이터 분석가 모집
# 5. [기어세컨드] 데이터 분석가 채용
# 6. Data Analyst (데이터 분석가)
# 7. 데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 8. [CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)
# 9. [인텔리전스랩스그룹] 데이터 분석가 (인게임 로그 및 비즈니스 인사이트 분석)
# 10. 데이터 분석가(신입/경력)
# 11. [다우키움 계열사] 데이터 분석가 (경력)
# 12. [통계팀] 데이터 분석가 모집
# 13. [커머스플랫폼팀] 데이터 분석 전문가 (Senior Data Analyst) 모집
# 14. [디저트39] 데이터 분석가(Data Analyst)/데이터 분석 엔지니어 팀장급
# 15. 데이터분석가 구인
# 16. [어니컴(주)] 데이터분석가 신입/경력 모집
# 17. [(중급이상/ 경력직)] 빅데이터 전문가를 모십니다
# 18. 데이터분석가 채용(경력)
# 19. [리비바이오] 데이터분석가
# 20. [INEEJI] (주)인이지 데이터분석가/AI엔지니어 전문가 채용

# %% [markdown]
# #### 6. 잡코리아에 '데이터 분석가' 직무 공고 제목을 수집하세요.
# - 셀레니움 코드로 크롤링 하기
# - 6개 페이지 크롤링 해오기
# - 서울지역 내 직무 공고 & 경력은 1~3년차만 크롤링하
# - 엑셀로 출력 (*해당 공고 타이틀과 지원할 수 있는 URL링크)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
results = []
for page_no in range(1,7):
    stext = "데이터 분석가"
    url = f"https://www.jobkorea.co.kr/Search/?stext={stext}&careerType=2&careerMin=1&careerMax=3&tabType=recruit&Page_No={page_no}&local=I000"
    print(f"\n======== {page_no}페이지 결과 ========")

    driver.get(url)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    titles = driver.find_elements(By.CSS_SELECTOR,"a.sn28bt0")
    for i, title in enumerate(titles,1):
        text = title.text.strip()
        link = title.get_attribute("href")
        print(f"{i}. {text} \n 링크 : {link}")
        results.append({
            "제목":text,
            "지원링크":link,
        })
        
    print("\n")
driver.quit()

df = pd.DataFrame(results)
df.to_excle("잡코리아_데이터분석가_서울_1-3년경력_6페이지 -1 .xlsx",index=False)
print("저장 완료")
# Out:
# ======== 1페이지 결과 ========
# 1. 데이터 분석가
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47247715?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=1&sc=630
# 2. [CVS] 데이터 분석가(Business Analyst)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47375996?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=2&sc=630
# 3. [기어세컨드] 데이터 분석가 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47074047?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=3&sc=630
# 4. 데이터 분석가(신입/경력)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47334852?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=4&sc=630
# 5. 데이터분석가 채용(경력)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47375766?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=5&sc=630
# 6. [INEEJI] (주)인이지 데이터분석가/AI엔지니어 전문가 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47338192?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=6&sc=630
# 7. [CJ그룹] CRM 데이터분석가 경력
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47266080?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=7&sc=630
# 8. (주)이엠넷 솔루션기획자 및 데이터분석가 경력직 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47267792?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=8&sc=630
# 9. 디지털 헬스케어 분야 데이터 분석 전문가(경력)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47391964?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=9&sc=630
# 10. [외국계광고] dentsu GA4 데이터 분석 전문가 정규직 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47391590?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=10&sc=630
# 11. 환경분야 빅데이터 분석 및 기획연구 담당자
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47383446?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=11&sc=630
# 12. 구글 애널리틱스 분석가 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47372382?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno
Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=44&sc=630
# 5. 우아한청년들에서 Business Analyst 모집중
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47309972?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=45&sc=630
# 6. [CS쉐어링/마곡본사] 데이터 통합 및 BI 자동화 담당자
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47315903?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=46&sc=630
# 7. [의료 분야] 대시보드 서비스기획자 경력직 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47416253?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=47&sc=630
# 8. AI 학습용 데이터 구축 사업 PM/PL 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47393081?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=48&sc=630
# 9. [DKBMC] Salesforce Global BA팀 신입/경력 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47329403?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=49&sc=630
# 10. 데이터 분석 (Data Scientist) 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47400206?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=50&sc=630
# 11. [서울/경기] 국비 전액지원 무료 취업교육생과정모집 (AI, 풀스택개발, 웹디자인/퍼블리싱, 게임/메타버스)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47064233?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=51&sc=630
# 12. [카운터포인트리서치] 마켓리서치 애널리스트 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47414226?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=52&sc=630
# 13. 모빌리티·교통 데이터 수집 및 분석 개발
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47221142?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=53&sc=630
# 14. 빅데이터 및 IT 컨설턴트/금융리스크관리 채용공고
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47251436?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=54&sc=630
# 15. [CFS] 쿠팡 물류 기획/운영 지원, data관리 [사원, 대리]
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47386478?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=55&sc=630
# 16. [kt ds] 2025년 부문별 경력사원 상시채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47376481?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=56&sc=630
# 17. 공공 분야 데이터 분석 및 인공지능 모델개발 경력자 모집 공고
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47155369?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=57&sc=630
# 18. Sr. DP Executive
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47384656?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=58&sc=630
# 19. 데이터기반 통합 마케팅 전략가(데이터분석가 팀 리더 모집)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47418067?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=59&sc=630
# 20. 한국마이크로의료로봇연구원 연구원(SW분야) 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47363645?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=60&sc=630
#
#
#
# ======== 4페이지 결과 ========
# 1. [데이터컨설턴트] 고객 문제 정의부터 분석까지 리딩할 인재 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47340164?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=61&sc=630
# 2. 익스피다이터스 코리아 [트레이드윈] 관세/무역 컨설턴트
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47327731?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=62&sc=630
# 3. [더파운더즈] CEO Staff팀 (Business Data)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47108298?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=63&sc=630
# 4. 직영점 운영 총괄 매니저 (4년차 - 10년차)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47338063?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=64&sc=630
# 5. [성수동] (주)씨케이앤비 서비스 개발 및 솔루션 개발 경력자 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47409288?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=65&sc=630
# 6. [무료교육] 데이터 시각화 엔지니어 훈련생 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47340919?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=66&sc=630
# 7. [nProtect] 중소기업 침해사고 피해지원 디지털 포렌식 담당자
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47375236?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=67&sc=630
# 8. [인공지능] LLM 개발자
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47401805?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=68&sc=630
# 9. 각 부문별 경력/신입 인재영입
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/45324861?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=69&sc=630
# 10. 주식 유튜브 센터 - [팀장, 센터장, 영상 전문가, 편집자, 사무보조] 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47383606?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=70&sc=630
# 11. ML(머신러닝) 엔지니어 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47343584?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=71&sc=630
# 12. 유튜브 증권방송 크리에이터 하절기 공개채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47075167?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=72&sc=630
# 13. (외국계 기업 나스닥 상장) Spotfire, Data분석, AI/ML 경력 정규직 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47399798?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=73&sc=630
# 14. 2025년 파고네트웍스 채용(네트워크 위협 분석가, Account Sales Manager, Channel Partner Sales Manager)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47323964?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=74&sc=630
# 15. 어세스타 역량사업본부 역량평가 과제개발자 경력직/신입사원 채용 공고
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/
Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=105&sc=630
# 6. [PTKOREA] 대기업 모바일 결제 서비스 마케팅
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47389508?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=106&sc=630
# 7. [PTKOREA] 채용 Sourcing 전문 인력 (계약직)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47366081?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=107&sc=630
# 8. [PTKOREA] D2C 마케팅 콘텐츠(라이브커머스) 기획자 (AE)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47389366?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=108&sc=630
# 9. [PTKOREA] 국내 대기업 온라인 패션몰 AMD (계약직)
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47389439?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=109&sc=630
# 10. [PTKOREA] 대기업 브랜드 프로모션 AE/PM
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47389394?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=110&sc=630
# 11. [PTKOREA] 글로벌 이커머스 플랫폼 UX 개선 PMO
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47332386?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=111&sc=630
# 12. [PTKOREA] 대기업 글로벌 웹사이트 콘텐츠 운영 및 확산 PM
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47332339?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=112&sc=630
# 13. 프로덕트 매니저(PM) 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47259218?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=113&sc=630
# 14. [PTKOREA] 글로벌 브랜드 사이트 운영 및 컨텐츠 Art Director, 콘텐츠제작
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47417844?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=114&sc=630
# 15. [서울역/산휴/1Y4M] GE Healthcare Marketing Communication 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47392665?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=115&sc=630
# 16. [Ingersoll Rand] BVT Product Manager
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47174485?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=116&sc=630
# 17. [겟앤쇼] 실적 분석 및 비주얼 콘텐츠 제작자 (과장급) 모집
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47425160?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=117&sc=630
# 18. 리서치 연구원 및 리서치 RA 채용
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47281337?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=118&sc=630
# 19. [소사지점/주식TM(경력자우대)]/업계1위/코인/레퍼럴/해선/화이트영업/
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47079990?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=119&sc=630
# 20. [신중동지점/주식TM(경력자우대)]/업계 1위/코인/레퍼럴/해선/유튜브DB/
#  링크 : https://www.jobkorea.co.kr/Recruit/GI_Read/47080024?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=120&sc=630
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 36
#      33     print("\n")
#      34 driver.quit()
# ---> 36 df = pd.DataFrame(results)
#      37 df.to_excle("잡코리아_데이터분석가_서울_1-3년경력_6페이지 -1 .xlsx",index=False)
#      38 print("저장 완료")
#
# NameError: name 'pd' is not defined

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By 
from selenium.webdriver.common.keys import Keys
import time
import urllib.parse
import pandas as pd

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "데이터 분석가"
encoded_query = urllib.parse.quote(query)

max_pages = 6

results = []
for page in range(1,max_pages +1):
    url = f"https://www.jobkorea.co.kr/Search?stext={encoded_query}&careerType=1&Page_No={page}&local=I000&tabType=recruit"
    driver.get(url)
    time.sleep(2)

    job_posts =driver.find_elements(By.CSS_SELECTOR, "div.styles_mb_space8__dk46ts1p")
    for post in job_posts :
        try : 
            title_elem = post.find_element(By.CSS_SELECTOR, "a.sn28bt0")
            title = title_elem.text.strip()
            link = title_elem.get_attribute("href")
            results.append({
                "제목" : title,
                "지원링크" : link
            })
        except :
            continue
driver.quit()

df = pd.DataFrame(results)
df.to_excel("잡코리아_데이터분석가_서울_신입_3페이지-1.xlsx",index=False)
print("엑셀저장완료")
# Out:
# 엑셀저장완료
