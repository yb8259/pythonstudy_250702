# %% [markdown]
# #### 1. 네이버 뉴스에서 '디지털 마케팅' 키워드로 검색한 뉴스 제목 10개를 수집하세요.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By 
import time

service=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

query = "디지털 마케팅"
url = f"https://search.naver.com/search.naver?where=news&query={query}"
driver.get(url)

elements = driver.find_elements(By.CSS_SELECTOR,"span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1.sds-comps-text-type-headline1")
for i, element in enumerate(elements[:10],1) :
        print(f"{i}. {element.text}")
driver.quit()
# Out:
# 1. 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공략
# 2. 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공동 공략
# 3. JT저축은행, 임직원 대상 챗GPT 교육 진행…디지털 역량 강화
# 4. 조선대, 인도네시아 에어랑가대학 대상 치과기술 마케팅 연수 개최
# 5. 롯데·신라免, 타겟 마케팅으로 부진 속 돌파구 찾는다
# 6. 정읍시, 전 직원 대상 SNS 홍보 교육"디지털 소통 강화"
# 7. SOOP, 2Q 영업익 300억·9.9%↓…'마케팅·인건비' 상승 영향
# 8. 국민체육진흥공단, '전국 대학생 스포츠 마케팅 경진 대회' 개최
# 9. 진화하는 은행 캐릭터 마케팅…신한은행 "금융 여정 동행 경험 심는다"
# 10. [Biz-inside,China] 쑥쑥 크는 中 전자상거래, AI로 무장하다…상담·마케...

# %%
import requests
from bs4 import BeautifulSoup

query = "디지털 마케팅"
url = f"https://search.naver.com/search.naver?where=news&query={query}"

headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
response =requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("a.ox1N67gcMkHhMh7hbfHi.VZxw34rcBHTWHgERxv0b")
for index, title in enumerate(titles[:10], 1) : 
    print(f"{index}. {title.get_text().strip()}")
# Out:
# 1. 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공동 공략
# 2. JT저축은행-한국폴리텍대학, 디지털 역량 강화 위한 챗GPT 교육
# 3. 조선대, 인도네시아 에어랑가대학 대상 치과기술 마케팅 연수 개최
# 4. SOOP, 2Q 영업익 300억·9.9%↓…'마케팅·인건비' 상승 영향
# 5. 롯데·신라免, 타겟 마케팅으로 부진 속 돌파구 찾는다
# 6. 국민체육진흥공단, '전국 대학생 스포츠 마케팅 경진 대회' 개최
# 7. 진화하는 은행 캐릭터 마케팅…신한은행 "금융 여정 동행 경험 심는다"
# 8. 다날·한컴위드, 스테이블코인 전자금융 사업 본격화 …"시장 최적화 디...
# 9. [Biz-inside,China] 쑥쑥 크는 中 전자상거래, AI로 무장하다…상담·마케...
# 10. 정읍시, 지황 농산물 가공식품 온라인 마케팅 강화교육 수료

# %% [markdown]
# #### 2. "다음 뉴스에서 IT섹션의 기사 제목과 링크를 수집하세요."

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/tech"
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

articles = soup.select("ul.list_newsheadline2 li a.item_newsheadline2")
for i, article in enumerate(articles, 1) :
    title = article.text.strip()
    link = article["href"]
    print(f"{i}. {title} - {link}")
# Out:
# 1. AI 핵심인재 키운다… 과기부, 생성형 AI·신진연구자 양성할 6개 기관 선정 [이데일리 김현아 기자]AI 산업 현장과 호흡을 맞추는 ‘산학협력형 인재 양성’이 본격화된다. 과학기술정보통신부(장관 배경훈)는 30일 ‘생성형 AI 선도인재양성’ 및 ‘AI 최고급 신진연구자 지원’ 사업의 신규 수행기관 6곳을 선정하고, 2025년 추경 예산을 통해 본격적인 AI 인재 양성에 착수한다고 밝혔다. 이번 사업은 AI 기술력뿐만 아니라 실제 이데일리 방금 전 - https://v.daum.net/v/20250730141403739
# 2. 수천만 개 사내문서도 '뚝딱'…日서 난리 난 AI가 국내산? 한국경제 3분 전 - https://v.daum.net/v/20250730141204652
# 3. 하반기 줄잇는 신작게임에 'MMORPG' 부활…"사활 걸었다" 머니투데이 3분 전 - https://v.daum.net/v/20250730141146624
# 4. 뜨거운 감자 '게임 질병코드'… 문체-복지, 엇갈린 답변에 대립각 재점화 전자신문 4분 전 - https://v.daum.net/v/20250730141104596
# 5. AI로 디지털 자신감 키운다…과학동아AiR 수업에서 몰입 효과 확인 동아사이언스 7분 전 - https://v.daum.net/v/20250730140804479
# 6. 네이처 “中 인재 유치 정책, 연구 능력 높였지만 내부 균열도 심화” 조선비즈 12분 전 - https://v.daum.net/v/20250730140257231
# 7. 폭염·열대야에도 생체 시계 고장 없는 이유…[달콤한 사이언스] 서울신문 13분 전 - https://v.daum.net/v/20250730140204159
# 8. [人사이트] 전명준 KT 데이터서비스담당 “디도스 공격 대형화 추세…클린존으로 기업 보안관될 것” 전자신문 22분 전 - https://v.daum.net/v/20250730135300778
# 9. 냅킨에 적은 아이디어가 5년 뒤 논문으로…"수학연구의 시작은 대화" 동아사이언스 27분 전 - https://v.daum.net/v/20250730134747596

# %% [markdown]
# #### 3. yes24의 경제 베스트셀러 1~10위 도서 제목과 저자를 수집하세요.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.yes24.com/product/category/steadyseller?categoryNumber=001001025007"
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
# response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")


books = soup.select("ul#yesBestList > li")
for i, book in enumerate(books[:10], 1) :
    title_tag = book.select_one("div.info_row.info_name a.gd_name")
    author_tag = book.select_one("span.authPub.info_auth")
    
    if title_tag and author_tag :
        title = title_tag.text.strip()
        author = author_tag.text.strip()
        print(f"{i}. {title} - {author}")
# Out:
# 1. 자본주의 - EBS 〈자본주의〉제작팀, 정지은, 고희정 저/EBS MEDIA 기획
# 2. 생각에 관한 생각 - 대니얼 카너먼 저/이창신 역
# 3. 더 그레이트 비트코인 - 오태민 저
# 4. 부의 추월차선 (10주년 스페셜 에디션) - 엠제이 드마코 저/신소영 역
# 5. 레버리지 - 롭 무어 저/김유미 역
# 6. 달러는 왜 비트코인을 싫어하는가 - 사이페딘 아모스 저/위대선 역
# 7. 넛지: 파이널 에디션 - 리처드 탈러, 캐스 선스타인 저/이경식 역/최정규 감수
# 8. 시대예보: 핵개인의 시대 - 송길영 저
# 9. 일할 사람이 사라진다 - 이철희 저
# 10. 경제신문이 말하지 않는 경제 이야기 - 임주영 저

# %% [markdown]
# #### 4. 기상청 날씨 페이지에서 오늘의 전국 날씨 요약을 추출하세요.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.weather.go.kr/w/weather/forecast/short-term.do"
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

summary_tag = soup.select_one("div.cmp-view-content > p.summary > span.depth_1")
if summary_tag :
    print(f"오늘의 전국 날씨 요약 : ")
    print(summary_tag.text.strip())
else :
    print("날씨 요약 정보를 찾을 수 없습니다!")
# Out:
# 오늘의 전국 날씨 요약 :
# □  (종합) 당분간 무더위와 열대야 주의, 전남해안과 경남남해안, 제주도해안 너울 유의

# %% [markdown]
# #### 5. 잡코리아에 '데이터 분석가' 직무 공고 제목 20개를 수집하세요.

# %%
import requests
from bs4 import BeautifulSoup

stext = "데이터 분석가"
url = f"https://www.jobkorea.co.kr/Search/?stext={stext}"
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("div.styles_mb_space8__dk46ts1p a.sn28bt0")
for i, title in enumerate(titles[0:20],1) :
    print(f"{i}. {title.text.strip()}")
# Out:
# 1. 데이터 분석가 (경력)
# 2. 데이터 분석가
# 3. [CVS] 데이터 분석가(Business Analyst)
# 4. [쿡앱스] 게임 데이터 분석가 모집
# 5. [기어세컨드] 데이터 분석가 채용
# 6. 데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 7. Data Analyst (데이터 분석가)
# 8. [CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)
# 9. [인텔리전스랩스그룹] 데이터 분석가 (인게임 로그 및 비즈니스 인사이트 분석)
# 10. 데이터 분석가(신입/경력)
# 11. 공공데이터 품질 관리와 진단, 데이터 분석가
# 12. [다우키움 계열사] 데이터 분석가 (경력)
# 13. [통계팀] 데이터 분석가 모집
# 14. [커머스플랫폼팀] 데이터 분석 전문가 (Senior Data Analyst) 모집
# 15. [디저트39] 데이터 분석가(Data Analyst)/데이터 분석 엔지니어 팀장급
# 16. 데이터분석가 구인
# 17. [어니컴(주)] 데이터분석가 신입/경력 모집
# 18. [(중급이상/ 경력직)] 빅데이터 전문가를 모십니다
# 19. 데이터분석가 채용(경력)
# 20. [리비바이오] 데이터분석가

# %% [markdown]
# #### 6. 잡코리아에 '데이터 분석가' 직무 공고 제목을 수집하세요.
# - 셀레니움 코드로 크롤링 하기
# - 6개 페이지 크롤링 해오기
# - 서울지역 내 직무 공고 & 경력은 1~3년차만 크롤링하
# - 엑셀로 출력 (*해당 공고 타이틀과 지원할 수 있는 URL링크)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By 
from selenium.webdriver.common.keys import Keys
import time

service=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)



headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
}

results = []

for page_no in range(1, 7):
    stext = "데이터 분석가"
    url = f"https://www.jobkorea.co.kr/Search/?stext={stext}&careerType=2&careerMin=1&careerMax=3&tabType=recruit&Page_No={page_no}&local=I000"
    print(f"\n======== {page_no}페이지 결과 ========")
    
    driver.get(url)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(2)

    titles = driver.find_elements(By.CSS_SELECTOR, "a.sn28bt0")
    for i, title in enumerate(titles, 1):
            text = title.text.strip()
            link = title.get_attribute("href")
            print(f"{i}. {text} \n   👉 링크: {link}")
            results.append({
                "제목" : text,
                "지원링크" : link
            })
    print("\n")

driver.quit()

df = pd.DataFrame(results)
df.to_excel("잡코리아_데이터분석가_서울_1-3년경력_6페이지.xlsx",index=False)
print("엑셀저장완료")
# Out:
# ======== 1페이지 결과 ========
# 1. 데이터 분석가
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47247715?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=1&sc=630
# 2. [CVS] 데이터 분석가(Business Analyst)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47375996?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=2&sc=630
# 3. [기어세컨드] 데이터 분석가 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47074047?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=3&sc=630
# 4. 데이터 분석가(신입/경력)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47334852?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=4&sc=630
# 5. 데이터분석가 채용(경력)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47375766?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=5&sc=630
# 6. [INEEJI] (주)인이지 데이터분석가/AI엔지니어 전문가 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47338192?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=6&sc=630
# 7. [CJ그룹] CRM 데이터분석가 경력
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47266080?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=7&sc=630
# 8. (주)이엠넷 솔루션기획자 및 데이터분석가 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47267792?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=8&sc=630
# 9. 디지털 헬스케어 분야 데이터 분석 전문가(경력)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47391964?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=9&sc=630
# 10. [외국계광고] dentsu GA4 데이터 분석 전문가 정규직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47391590?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=10&sc=630
# 11. 구글 애널리틱스 분석가 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47372382?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=11&sc=630
# 12. 스포카 키친보드 사업팀 CS파트 고객성공 매니저(Junior) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47095155?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=12&sc=630
# 13. 환경분야 빅데이터 분석 및 기획연구 담당자
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47383446?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=13&sc=630
# 14. 스포카 키친보드 사업팀 세일즈 매니저(Junior) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47095151?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=14&sc=630
# 15. [NHN PAYCO] 데이터 엔지니어 - BI 시스템 개발
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47241604?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=15&sc=630
# 16. 인하우스 전자담배사 브랜드기획팀 퍼포먼스 마케터 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47400219?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=16&sc=630
# 17. Data Analyst
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47406110?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=17&sc=630
# 18. [토스페이먼츠] Data Analyst
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47405080?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=18&sc=630
# 19. [신입/경력] 비즈마켓 전략기획실, 제안서 작성 / 분석가 채용공고
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47169473?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=19&sc=630
# 20. Data Analyst (3년 이상)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47273224?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=20&sc=630
#
#
#
# ======== 2페이지 결과 ========
# 1. 마케팅 데이터 애널리스트 (3년 이상)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47107503?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=21&sc=630
# 2. [푸드팡] DataOps Manager (Data Analyst)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47354925?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=22&sc=630
# 3. [아이즈비전] MNO 온라인개통 사원 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47325624?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=23&sc=630
# 4. [아이즈비전] IT개발팀(웹,MVNO전산 개발/운영) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47300567?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=24&sc=630
# 5. Data Analyst-글로벌 K팝 플랫폼(Mnet Plus)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47201114?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=25&sc=630
# 6. [AI 헬스케어] 마케팅 데이터 분석가 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47338309?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=26&sc=630
# 7. 인피닉 AI연구소 공간 데이터 분석가 채용(Spatial Scientist)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47284904?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=27&sc=630
# 8. [토스플레이스 자회사/아이샵케어] Data Analyst (데이터 분석가)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47416209?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=28&sc=630
# 9. [메드트로닉 코리아]Channel Data Analyst (계약직채용)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47384971?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=29&sc=630
# 10. 연합인포맥스 콘텐츠기획본부 개발 및 기획부문 신입/경력 사원 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47368634?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=30&sc=630
# 11. 현대해상 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47340010?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=31&sc=630
# 12. [CJ그룹-디엑스이] CRM 데이터분석가 경력채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47265151?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=32&sc=630
# 13. [인턴십연계] 이스트소프트 정보보안·AI 프론트엔드 교육생 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47350113?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=33&sc=630
# 14. (취업연계과정)[더존비즈온] Cloud DX Academy 4기 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47377837?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=34&sc=630
# 15. (외국계 기업 나스닥 상장) Spotfire, Data분석, AI/ML 경력 정규직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47399798?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=35&sc=630
# 16. 2025년 7월 데이터 전문가 계약직 채용 (장애인 우대)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47317150?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=36&sc=630
# 17. 하반기 부문별 모집 (스포츠 마케팅/제작PD(영상팀)/웹서버 개발자)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47412009?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=37&sc=630
# 18. [토스플레이스] DataOps Manager
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47384807?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=38&sc=630
# 19. SCM팀 Business Analyst 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47133561?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=39&sc=630
# 20. FP & A Analyst
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47391213?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=40&sc=630
#
#
#
# ======== 3페이지 결과 ========
# 1. 우아한청년들에서 Business Analyst 모집중
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47309972?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=41&sc=630
# 2. [삼성역/외국계의료기기] Finance Analyst (경력 2년 이상)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47244113?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=42&sc=630
# 3. [서울/경기] 'AI' 전액지원 무료 취업교육생과정 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47233128?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=43&sc=630
# 4. 신입 IT 기술엔지니어 (포렌식) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47305338?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=44&sc=630
# 5. [CS쉐어링/마곡본사] 데이터 통합 및 BI 자동화 담당자
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47315903?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=45&sc=630
# 6. AI 학습용 데이터 구축 사업 PM/PL 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47393081?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=46&sc=630
# 7. [DKBMC] Salesforce Global BA팀 신입/경력 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47329403?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=47&sc=630
# 8. 데이터 분석 (Data Scientist) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47400206?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=48&sc=630
# 9. [성수동] (주)씨케이앤비 서비스 개발 및 솔루션 개발 경력자 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47409288?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=49&sc=630
# 10. 모빌리티 데이터 수집 시스템 개발
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47221142?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=50&sc=630
# 11. [서울/경기] 국비 전액지원 무료 취업교육생과정모집 (AI, 풀스택개발, 웹디자인/퍼블리싱, 게임/메타버스)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47064233?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=51&sc=630
# 12. 빅데이터 및 IT 컨설턴트/금융리스크관리 채용공고
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47251436?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=52&sc=630
# 13. [CFS] 쿠팡 물류 기획/운영 지원, data관리 [사원, 대리]
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47386478?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=53&sc=630
# 14. [kt ds] 2025년 부문별 경력사원 상시채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47376481?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=54&sc=630
# 15. 공공 분야 데이터 분석 및 인공지능 모델개발 경력자 모집 공고
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47155369?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=55&sc=630
# 16. Sr. DP Executive
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47384656?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=56&sc=630
# 17. [데이터컨설턴트] 고객 문제 정의부터 분석까지 리딩할 인재 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47340164?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=57&sc=630
# 18. 직영점 운영 총괄 매니저 (4년차 - 10년차)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47338063?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=58&sc=630
# 19. 익스피다이터스 코리아 [트레이드윈] 관세/무역 컨설턴트
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47327731?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=59&sc=630
# 20. 한국마이크로의료로봇연구원 연구원(SW분야) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47363645?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=60&sc=630
#
#
#
# ======== 4페이지 결과 ========
# 1. [더파운더즈] CEO Staff팀 (Business Data)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47108298?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=61&sc=630
# 2. 주식 유튜브 센터 - [팀장, 센터장, 영상 전문가, 편집자, 사무보조] 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47383606?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=62&sc=630
# 3. [무료교육] 데이터 시각화 엔지니어 훈련생 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47340919?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=63&sc=630
# 4. [nProtect] 중소기업 침해사고 피해지원 디지털 포렌식 담당자
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47375236?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=64&sc=630
# 5. [인공지능] LLM 개발자
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47401805?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=65&sc=630
# 6. 각 부문별 경력/신입 인재영입
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/45324861?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=66&sc=630
# 7. 유튜브 증권방송 크리에이터 하절기 공개채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47075167?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=67&sc=630
# 8. ML(머신러닝) 엔지니어 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47343584?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=68&sc=630
# 9. 2025년 파고네트웍스 채용(네트워크 위협 분석가, Account Sales Manager, Channel Partner Sales Manager)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47323964?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=69&sc=630
# 10. 어세스타 역량사업본부 역량평가 과제개발자 경력직/신입사원 채용 공고
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47388872?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=70&sc=630
# 11. [주식/코인유튜브 크리에이터] 코인,주식 영상DB수집(얼굴X) /부천 상동
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47088887?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=71&sc=630
# 12. [에이아이매틱스] 연구개발(CAN리버스 / 백엔드 / 테스트엔지니어 / 임베디드시스템)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47205287?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=72&sc=630
# 13. ㈜케이스랩 각 부문별 인재 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47402487?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=73&sc=630
# 14. [의료 분야] 데이터분석가 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47414988?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=74&sc=630
# 15. 데이터기반 통합 마케팅 전략가(데이터분석가 팀 리더 모집)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47418067?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=75&sc=630
# 16. (주)임팩티브AI 25년 부문별 정규직 경력 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47359726?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=76&sc=630
# 17. 빔산토리코리아 영업사원(신입/경력) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47333527?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=77&sc=630
# 18. 교육서비스 기획자 경력
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47231061?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=78&sc=630
# 19. [경력3년이상] 개인신용정보 데이터 분석 및 모델링
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47414832?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=79&sc=630
# 20. [SK렌터카] Pricing 데이터 분석 (계약직)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47418304?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=80&sc=630
#
#
#
# ======== 5페이지 결과 ========
# 1. UX/UI Planner - 생성형 AI 서비스 기획 및 디자인
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47299244?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=81&sc=630
# 2. Global IT보안관제센터(Asia 지역 담당) 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47324624?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=82&sc=630
# 3. [육휴대체/재택] 바비톡 Product Designer 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47272883?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=83&sc=630
# 4. 월트디즈니컴퍼니코리아 국제노동기준 담당자 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47277807?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=84&sc=630
# 5. [컴투스홀딩스] 데이터분석 담당자 (3-8년차)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47197997?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=85&sc=630
# 6. 코인 유튜브 영상 촬영 전문가 채용 [겸업0, 재택근무, 얼굴X]
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47367983?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=86&sc=630
# 7. 코인현물/선물 트레이딩 전문가 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47161650?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=87&sc=630
# 8. 삼성생명 법인사업부 -기업컨설팅센터 기업재무상담 (예비)전문가
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47413100?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=88&sc=630
# 9. [의료 분야] 대시보드 서비스기획자 경력직 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47416253?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=89&sc=630
# 10. [코인TM / 코인레퍼럴] 코인 TM 영업 채용 (부천 본사 / 자체생산 DB / 단순TM / 기숙사 보유)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47088885?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=90&sc=630
# 11. [㈜대한파트너스] 코인레퍼럴 TM영업 공개채용 (서울 가산 / 자체생산 DB / 주급)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47088896?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=91&sc=630
# 12. Job Description: Junior Business Analyst
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47342299?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=92&sc=630
# 13. [유튜브 코인 전문가 공개 채용] 그레이스체인에서 동종 업계 최고의 대우
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47378039?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=93&sc=630
# 14. [서울/경력 3년 이상] UXA팀- UX 리서치 분석가
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47194672?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=94&sc=630
# 15. [PTKOREA] 퍼포먼스 마케터
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389408?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=95&sc=630
# 16. IT 기획관리자
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47229812?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=96&sc=630
# 17. [PTKOREA] 대기업 글로벌 앱 마케팅
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389374?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=97&sc=630
# 18. 영어교재 컨텐츠 개발 팀장 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47229790?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=98&sc=630
# 19. [블록체인 웹/앱 서비스 기획자]
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47360909?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=99&sc=630
# 20. 리딩스타(주) IT 기획관리자 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47229614?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=100&sc=630
#
#
#
# ======== 6페이지 결과 ========
# 1. [PTKOREA] 글로벌 소셜 채널 운영 (계약직)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389314?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=101&sc=630
# 2. 프로덕트 매니저(PM)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47261508?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=102&sc=630
# 3. [PTKOREA] Digital Marketing 자산 제작 관리 AE/ 갤러리 이미지 AE
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389513?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=103&sc=630
# 4. [PTKOREA] 검색 퍼포먼스 마케터
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389476?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=104&sc=630
# 5. [PTKOREA] 글로벌 사이트 콘텐츠 디자이너
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47366127?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=105&sc=630
# 6. [PTKOREA] 사이트 UI/UX 디자이너
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47417781?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=106&sc=630
# 7. 세일즈매니저(Account Executive)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47285408?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=107&sc=630
# 8. [PTKOREA] 국내 대기업 온라인 패션몰 AMD (계약직)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389439?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=108&sc=630
# 9. [PTKOREA] 대기업 모바일 결제 서비스 마케팅
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389508?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=109&sc=630
# 10. [PTKOREA] 채용 Sourcing 전문 인력 (계약직)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47366081?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=110&sc=630
# 11. [PTKOREA] D2C 마케팅 콘텐츠(라이브커머스) 기획자 (AE)
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389366?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=111&sc=630
# 12. [PTKOREA] 글로벌 브랜드 사이트 운영 및 컨텐츠 Art Director, 콘텐츠제작
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47417844?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=112&sc=630
# 13. [PTKOREA] 대기업 브랜드 프로모션 AE/PM
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47389394?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=113&sc=630
# 14. [PTKOREA] 글로벌 이커머스 플랫폼 UX 개선 PMO
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47332386?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=114&sc=630
# 15. [PTKOREA] 대기업 글로벌 웹사이트 콘텐츠 운영 및 확산 PM
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47332339?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=115&sc=630
# 16. 프로덕트 매니저(PM) 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47259218?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=116&sc=630
# 17. [서울역/산휴/1Y4M] GE Healthcare Marketing Communication 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47392665?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=117&sc=630
# 18. [Ingersoll Rand] BVT Product Manager
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47174485?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=118&sc=630
# 19. [카운터포인트리서치] 마켓리서치 애널리스트 모집
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47414226?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=119&sc=630
# 20. 리서치 연구원 및 리서치 RA 채용
#    👉 링크: https://www.jobkorea.co.kr/Recruit/GI_Read/47281337?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=120&sc=630
#
#
# 엑셀저장완료

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By 
from selenium.webdriver.common.keys import Keys
import time
import urllib.parse
import pandas as pd

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

query = "데이터 분석가"
encoded_query = urllib.parse.quote(query)

max_pages = 6

results = []

for page in range(1, max_pages + 1) :
    url = f"https://www.jobkorea.co.kr/Search?stext={encoded_query}&careerType=1&Page_No={page}&local=I000&tabType=recruit"
    driver.get(url)
    time.sleep(2)

    job_posts = driver.find_elements(By.CSS_SELECTOR, "div.styles_mb_space8__dk46ts1p")
    for post in job_posts : 
        try : 
            title_elem = post.find_element(By.CSS_SELECTOR, "a.sn28bt0")
            title = title_elem.text.strip()
            link = title_elem.get_attribute("href")
            results.append({
                "제목" : title,
                "지원링크" : link
            })
        except :
            continue
driver.quit()

df = pd.DataFrame(results)
df.to_excel("잡코리아_데이터분석가_서울_신입_3페이지.xlsx",index=False)
print("엑셀저장완료")
# Out:
# [{'제목': '[CVS] 데이터 분석가(Business Analyst)', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47375996?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=1&sc=630'}, {'제목': '[CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47376045?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=2&sc=630'}, {'제목': '공공데이터 품질 관리와 진단, 데이터 분석가', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47335611?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=3&sc=630'}, {'제목': '[INEEJI] (주)인이지 데이터분석가/AI엔지니어 전문가 채용', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47338192?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=4&sc=630'}, {'제목': '디지털 헬스케어 분야 데이터 분석 전문가(신입)', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47399254?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=5&sc=630'}, {'제목': '[이든] 쇼핑 로직 분석가 신입 채용', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47405394?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=6&sc=630'}, {'제목': '환경분야 빅데이터 분석 및 기획연구 담당자', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47383446?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=7&sc=630'}, {'제목': '[신입/경력] 비즈마켓 전략기획실, 제안서 작성 / 분석가 채용공고', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47169473?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=8&sc=630'}, {'제목': '인피닉 AI연구소 공간 데이터 분석가 채용(Spatial Scientist)', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47284904?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=9&sc=630'}, {'제목': '연합인포맥스 콘텐츠기획본부 개발 및 기획부문 신입/경력 사원 모집', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47368634?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=10&sc=630'}, {'제목': '[인턴십연계] 이스트소프트 정보보안·AI 프론트엔드 교육생 모집', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47350113?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=11&sc=630'}, {'제목': '(취업연계과정)[더존비즈온] Cloud DX Academy 4기 모집', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47377837?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=12&sc=630'}, {'제목': '하반기 부문별 모집 (스포츠 마케팅/제작PD(영상팀)/웹서버 개발자)', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47412009?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=13&sc=630'}, {'제목': "[서울/경기] 'AI' 전액지원 무료 취업교육생과정 모집", '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47233128?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=14&sc=630'}, {'제목': '[티사이언티픽] AI 데이터 기획자 채용', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47287041?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=15&sc=630'}, {'제목': '[DKBMC] Salesforce Global BA팀 신입/경력 채용', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47329403?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=16&sc=630'}, {'제목': '데이터 분석 (Data Scientist) 채용', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47400206?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=17&sc=630'}, {'제목': '[미리디] 데이터 분석', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47298432?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=18&sc=630'}, {'제목': '[서울/경기] 국비 전액지원 무료 취업교육생과정모집 (AI, 풀스택개발, 웹디자인/퍼블리싱, 게임/메타버스)', '지원링크': 'https://www.jobkorea.co.kr/Recruit/GI_Read/47064233?Oem_Code=C1&logpath=1&stext=%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B0%80&listno=19&sc=630'}, {'제목': ...
# 엑셀저장완료
